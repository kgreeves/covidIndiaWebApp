# %%
import os
import json
import pandas as pd
from pathlib import Path

# %%
BASE_PATH = Path(os.path.abspath('')).parent.absolute()

# %%
f = open(str(BASE_PATH)+'\\data\\states.json')
indian_states = json.load(f)

f = open(str(BASE_PATH)+'\\data\\state_district_wise.json')
indian_covid_json  = json.load(f)

# %%
# JSON of Covid Data to pd (index=district)
state_pd = []

for state in indian_states['features']:
    
    curr_state = state['id']
    
    current_state_pd = pd.DataFrame(indian_covid_json[curr_state]['districtData']).T
    
    for status in current_state_pd.iloc[0,:]['delta'].keys():
        current_state_pd[f'delta.{status}'] = current_state_pd['delta'].apply(lambda x: x[status])
        
    current_state_pd.drop(columns=['delta'], inplace=True)
    
    current_state_pd['state'] = curr_state
    
    state_pd.append(current_state_pd)
    
full_data = pd.concat(state_pd)

# %%
full_data = full_data.astype(dtype={
    "notes":"object",
    "active":"int64",
    "confirmed":"int64",
    "migratedother":"int64",
    "deceased":"int64",
    "recovered":"int64",
    "delta.confirmed":"int64",
    "delta.deceased":"int64",
    "delta.recovered":"int64",
    "state":"object"
})

# %%
full_data.dtypes
# Out:
# notes              object
# active              int64
# confirmed           int64
# migratedother       int64
# deceased            int64
# recovered           int64
# delta.confirmed     int64
# delta.deceased      int64
# delta.recovered     int64
# state              object
# dtype: object

# %%
covid_state_data = (
    full_data
    .groupby(by='state')
    .sum(numeric_only=True)
    .reset_index()
    .rename(columns={'state' : 'id'})
)

# %%
geo_data_pd = []

for state in indian_states['features']:
    geo_data_pd.append(pd.DataFrame(pd.json_normalize(state)))
    
full_geo_data = (pd.concat(geo_data_pd)
                 .drop(columns=['type','total'])
                 .rename(columns={'id' : 'state'})
                 .set_index('state'))

# %%
covid_geo_pd = covid_state_data.merge(full_geo_data, on='state')

# %%
with open('covid_geo_india.json','w') as file:
    file.write(covid_geo_pd.T.to_json())

# %%
(covid_geo_pd
)
# Out:
#                    id  active  confirmed  migratedother  deceased  recovered  \
# 0      Andhra Pradesh   18417    1987051              0     13582    1955052
# 1   Arunachal Pradesh    2488      50793              0       251      48054
# 2               Assam    -373     577035           1347      5434     560782
# 3               Bihar     276     725326              1      9646     715403
# 4        Chhattisgarh    1557    1003439              0     13545     988337
# 5               Delhi     494    1436889              0     25068    1411327
# 6                 Goa     983     172188              0      3164     168041
# 7             Gujarat     194     825101              0     10077     814830
# 8             Haryana     670     770130              0      9653     759807
# 9    Himachal Pradesh    2556     208990             18      3523     202893
# 10  Jammu and Kashmir    1297     322885              0      4393     317195
# 11          Jharkhand     196     347454              0      5130     342128
# 12          Karnataka   22851    2922875             26     36881    2863117
# 13             Kerala  175958    3610193            520     18120    3415595
# 14     Madhya Pradesh     132     791990              0     10514     781344
# 15        Maharashtra   64570    6369002           3448    134364    6166620
# 16            Manipur    6857     106030              0      1674      97499
# 17          Meghalaya    4496      70232              0      1195      64541
# 18            Mizoram   11414      46320              0       172      34734
# 19           Nagaland    1351      28875            832       591      26101
# 20             Odisha    9813     990075              0      6683     973579
# 21             Punjab     517     599678              0     16325     582836
# 22          Rajasthan     195     953870              0      8954     944721
# 23             Sikkim    2543      28175            278       359      24995
# 24         Tamil Nadu   20382    2581094              0     34395    2526317
# 25            Tripura    2076      80657             63       770      77748
# 26      Uttar Pradesh     505    1708836              0     22776    1685555
# 27        Uttarakhand     435     342502           6040      7369     328658
# 28        West Bengal   10163    1535699              0     18258    1507278
#
#     delta.confirmed  delta.deceased  delta.recovered geometry.type  \
# 0              1869              18             2316  MultiPolygon
# 1               188               3              233       Polygon
# 2               886              14                0       Polygon
# 3                47               0               51       Polygon
# 4                83               1              148       Polygon
# 5                 0               0                0       Polygon
# 6                 0               0                0       Polygon
# 7                16               0               28  MultiPolygon
# 8                16               1               17       Polygon
# 9               374               2              138       Polygon
# 10              114               1              114       Polygon
# 11               14               0               26       Polygon
# 12             1826              33             1618       Polygon
# 13            23500             116            19411       Polygon
# 14               10               0                0       Polygon
# 15             5560             163             6944       Polygon
# 16              606              10                0       Polygon
# 17              463              10              384       Polygon
# 18              863               1             1012       Polygon
# 19               64               6               78       Polygon
# 20             1078              65              869  MultiPolygon
# 21              105               3               45       Polygon
# 22               19               0               21       Polygon
# 23              157               0                0       Polygon
# 24             1964              28             1917  MultiPolygon
# 25              244               2              210       Polygon
# 26               24               1               63       Polygon
# 27               40               1               48       Polygon
# 28              700               6              746  MultiPolygon
#
#                                  geometry.coordinates
# 0   [[[[80.149167, 13.6183], [80.142031, 13.544708...
# 1   [[[95.237733, 26.686434], [95.216325, 26.73549...
# 2   [[[95.952244, 27.941956], [95.758675, 27.72653...
# 3   [[[88.105565, 26.53925], [88.14526, 26.511152]...
# 4   [[[84.002706, 22.520688], [83.975945, 22.50240...
# 5   [[[77.186759, 28.866984], [77.217534, 28.83531...
# 6   [[[74.126229, 15.650328], [74.190009, 15.68110...
# 7   [[[[72.676692, 21.155893], [72.710589, 21.1407...
# 8   [[[77.574789, 30.384315], [77.570329, 30.31116...
# 9   [[[78.907025, 31.259389], [78.996674, 31.11532...
# 10  [[[78.410615, 32.511789], [78.382516, 32.52963...
# 11  [[[87.599788, 25.314503], [87.684084, 25.31004...
# 12  [[[77.549813, 18.291161], [77.602888, 18.27778...
# 13  [[[74.995951, 12.787827], [74.984801, 12.72984...
# 14  [[[82.807841, 23.963089], [82.656643, 23.90778...
# 15  [[[74.435761, 22.030967], [74.448695, 21.97120...
# 16  [[[93.337279, 24.053183], [93.255213, 24.02374...
# 17  [[[91.853845, 26.104835], [91.922084, 25.99957...
# 18  [[[92.800727, 24.418912], [92.83284, 24.376541...
# 19  [[[95.214541, 26.937093], [95.233719, 26.89070...
# 20  [[[[84.760925, 19.071235], [84.73015, 19.08952...
# 21  [[[75.868796, 32.488597], [75.932129, 32.41678...
# 22  [[[73.889397, 29.977552], [74.519165, 29.94321...
# 23  [[[88.751835, 27.148056], [88.559158, 27.18864...
# 24  [[[[79.31245, 9.328562], [79.32583, 9.26166], ...
# 25  [[[92.23117, 24.5041], [92.272649, 24.379217],...
# 26  [[[83.856414, 27.348315], [83.828761, 27.32289...
# 27  [[[80.058627, 28.835317], [80.03365, 28.761279...
# 28  [[[[88.497609, 21.599674], [88.531506, 21.5425...
